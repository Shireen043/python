# %%
import openpyxl
import pandas as pd

# %%
workbook = openpyxl.Workbook()
sheet = workbook.active

# %%
data = [
     ['NAME', 'DOMAIN','AGE','LOCATION','SALARY','EXP'],
     ['ALEX',  'TESTING', 25 , 'BNG',5000,2],
     ['BARB','JAVA',30,'CHE',10000,3],
     ['CHERRY','C',35,'PUNE',15000,4],
     ['DIPAN','DA',38,'MUMBAI',20000,5],
     ['ESHWAR','DS', 40, 'HYD' ,50000 ,6]]

# %%
for row in data:
    sheet.append(row)

# %%
workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
#  ['ALEX', 'TESTING', 25, 'BNG', 5000, 2],
#  ['BARB', 'JAVA', 30, 'CHE', 10000, 3],
#  ['CHERRY', 'C', 35, 'PUNE', 15000, 4],
#  ['DIPAN', 'DA', 38, 'MUMBAI', 20000, 5],
#  ['ESHWAR', 'DS', 40, 'HYD', 50000, 6]]

# %%
import os   # to check where data stored
os.getcwd()
# Out:
# 'C:\\Users\\acer'

# %%
emp=pd.read_excel(r"C:\Users\acer\data.xlsx")
emp
# Out:
#      NAME   DOMAIN  AGE LOCATION  SALARY  EXP
# 0    ALEX  TESTING   25      BNG    5000    2
# 1    BARB     JAVA   30      CHE   10000    3
# 2  CHERRY        C   35     PUNE   15000    4
# 3   DIPAN       DA   38   MUMBAI   20000    5
# 4  ESHWAR       DS   40      HYD   50000    6

# %%
emp.shape # it has five rows and 6 clms (dimensions)
# Out:
# (5, 6)

# %%
emp.columns  # column names
# Out:
# Index(['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp)
# Out:
# 5

# %%
emp
# Out:
#      NAME   DOMAIN  AGE LOCATION  SALARY  EXP
# 0    ALEX  TESTING   25      BNG    5000    2
# 1    BARB     JAVA   30      CHE   10000    3
# 2  CHERRY        C   35     PUNE   15000    4
# 3   DIPAN       DA   38   MUMBAI   20000    5
# 4  ESHWAR       DS   40      HYD   50000    6

# %%
emp['SALARY']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    50000
# Name: SALARY, dtype: int64

# %%
emp[['SALARY','EXP']]
# Out:
#    SALARY  EXP
# 0    5000    2
# 1   10000    3
# 2   15000    4
# 3   20000    5
# 4   50000    6

# %%
import numpy as np # ND ARRAY
import matplotlib.pyplot as plt # VISUALIZATION
import seaborn as sns  # STATISTIC VISUALIZATION

# %%
vis1 = sns.displot(emp['SALARY'])

# %%
vis2 = sns.distplot(emp['SALARY'])
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_9224\826855712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2 = sns.distplot(emp['SALARY'])

# %%
vis3= plt.hist(emp['SALARY'])

# %%
plt.rcParams['figure.figsize']=5,1

# %%
vis5=sns.lmplot(data=emp,x='EXP',y='SALARY')  # bivariate

# %%
vis6=sns.lmplot(data=emp, x= 'EXP' , y = 'SALARY',fit_reg=False)

# %%
vis6=sns.lmplot(data=emp, x= 'EXP' , y = 'SALARY',fit_reg=True)  # linear model(lm)
